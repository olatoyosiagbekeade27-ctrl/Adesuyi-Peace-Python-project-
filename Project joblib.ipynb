# %%
import joblib as jb

# %%
model = jb.load("Churn_data.joblib")

# %%
new_customer = [(1,1,50,30,8000,3,1,1,105969,2)]

# %%
predictions = model.predict(new_customer)
# Out:
# C:\Users\USER PC\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
predictions
# Out:
# array([1], dtype=int64)

# %%
new_customers = [(0,0,29,67,42290.14,2,1,0,117422.959,2)]

# %%
prediction = model.predict(new_customers)
# Out:
# C:\Users\USER PC\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array([0], dtype=int64)
